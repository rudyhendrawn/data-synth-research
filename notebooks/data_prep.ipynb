# %% [markdown]
# - 01: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# - 02: https://www.kaggle.com/datasets/mastmustu/insurance-claims-fraud-data/data
# - 03: https://www.kaggle.com/datasets/shivamb/vehicle-claim-fraud-detection
# - 04: https://www.kaggle.com/datasets/sgpjesus/bank-account-fraud-dataset-neurips-2022
# - 05: https://www.kaggle.com/datasets/rupakroy/online-payments-fraud-detection-dataset
# - 06: https://www.kaggle.com/datasets/nelgiriyewithana/credit-card-fraud-detection-dataset-2023
# - 09: https://data.mendeley.com/datasets/552r52kmgb/1

# %%
import pandas as pd
import os

data_path = "/Users/rudyhendrawan/Projects/data"

# %% [markdown]
# ## Credit Card

# %%
df = pd.read_csv(os.path.join(data_path, '01_creditcard.csv'))
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# ## Insurance

# %%
df_insurance_data = pd.read_csv(os.path.join(data_path, '02_insurance_data.csv'))
df_insurance_vendor = pd.read_csv(os.path.join(data_path, '02_vendor_data.csv'))
df_insurance_employee = pd.read_csv(os.path.join(data_path, '02_employee_data.csv'))



df_insurance_all = pd.merge(df_insurance_data, df_insurance_employee, on='AGENT_ID', how='left', suffixes=('_CUSTOMER','_AGENT'))
df_insurance_all = pd.merge(df_insurance_all, df_insurance_vendor, on='VENDOR_ID', how='left')
df_insurance_all.head()
# Out:
#          TXN_DATE_TIME TRANSACTION_ID CUSTOMER_ID POLICY_NUMBER POLICY_EFF_DT  \
# 0  2020-06-01 00:00:00    TXN00000001   A00003822   PLC00008468    2015-06-23
# 1  2020-06-01 00:00:00    TXN00000002   A00008149   PLC00009594    2018-04-21
# 2  2020-06-01 00:00:00    TXN00000003   A00003172   PLC00007969    2019-10-03
# 3  2020-06-01 00:00:00    TXN00000004   A00007572   PLC00009292    2016-11-29
# 4  2020-06-01 00:00:00    TXN00000005   A00008173   PLC00000204    2011-12-26
#
#       LOSS_DT   REPORT_DT INSURANCE_TYPE  PREMIUM_AMOUNT  CLAIM_AMOUNT  ...  \
# 0  2020-05-16  2020-05-21         Health          157.13          9000  ...
# 1  2020-05-13  2020-05-18       Property          141.71         26000  ...
# 2  2020-05-21  2020-05-26       Property          157.24         13000  ...
# 3  2020-05-14  2020-05-19         Health          172.87         16000  ...
# 4  2020-05-17  2020-05-22         Travel           88.53          3000  ...
#
# ...

# %% [markdown]
# ## Vehicle Insurance Claim

# %%
df_vehicle = pd.read_csv(os.path.join(data_path, '03_fraud_oracle.csv'))
df_vehicle.head()
# Out:
#   Month  WeekOfMonth  DayOfWeek    Make AccidentArea DayOfWeekClaimed  \
# 0   Dec            5  Wednesday   Honda        Urban          Tuesday
# 1   Jan            3  Wednesday   Honda        Urban           Monday
# 2   Oct            5     Friday   Honda        Urban         Thursday
# 3   Jun            2   Saturday  Toyota        Rural           Friday
# 4   Jan            5     Monday   Honda        Urban          Tuesday
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  AgeOfVehicle  \
# 0          Jan                   1  Female        Single  ...       3 years
# 1          Jan                   4    Male        Single  ...       6 years
# 2          Nov                   2    Male       Married  ...       7 years
# 3          Jul                   1    Male       Married  ...   more than 7
# 4          Feb                   2  Female        Single  ...       5 years
#
#   AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# ...

# %%
df_vehicle.shape
# Out:
# (15420, 33)

# %%
df_vehicle['FraudFound_P'].value_counts()
# Out:
# FraudFound_P
# 0    14497
# 1      923
# Name: count, dtype: int64

# %%
df_vehicle.isna().sum()
# Out:
# Month                   0
# WeekOfMonth             0
# DayOfWeek               0
# Make                    0
# AccidentArea            0
# DayOfWeekClaimed        0
# MonthClaimed            0
# WeekOfMonthClaimed      0
# Sex                     0
# MaritalStatus           0
# Age                     0
# Fault                   0
# PolicyType              0
# VehicleCategory         0
# VehiclePrice            0
# FraudFound_P            0
# PolicyNumber            0
# RepNumber               0
# Deductible              0
# DriverRating            0
# Days_Policy_Accident    0
# Days_Policy_Claim       0
# PastNumberOfClaims      0
# AgeOfVehicle            0
# AgeOfPolicyHolder       0
# PoliceReportFiled       0
# WitnessPresent          0
# AgentType               0
# NumberOfSuppliments     0
# AddressChange_Claim     0
# NumberOfCars            0
# Year                    0
# BasePolicy              0
# dtype: int64

# %%
df_vehicle.dtypes
# Out:
# Month                   object
# WeekOfMonth              int64
# DayOfWeek               object
# Make                    object
# AccidentArea            object
# DayOfWeekClaimed        object
# MonthClaimed            object
# WeekOfMonthClaimed       int64
# Sex                     object
# MaritalStatus           object
# Age                      int64
# Fault                   object
# PolicyType              object
# VehicleCategory         object
# VehiclePrice            object
# FraudFound_P             int64
# PolicyNumber             int64
# RepNumber                int64
# Deductible               int64
# DriverRating             int64
# Days_Policy_Accident    object
# Days_Policy_Claim       object
# PastNumberOfClaims      object
# AgeOfVehicle            object
# AgeOfPolicyHolder       object
# PoliceReportFiled       object
# WitnessPresent          object
# AgentType               object
# NumberOfSuppliments     object
# AddressChange_Claim     object
# ...

# %% [markdown]
# ## Bank Account Fraud

# %%
df_bank_account = pd.read_csv(os.path.join(data_path, '04_bank_account.csv'))
    
df_bank_account.head()
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.3               0.986506                         -1
# 1           0     0.8               0.617426                         -1
# 2           0     0.8               0.996707                          9
# 3           0     0.6               0.475100                         11
# 4           0     0.9               0.842307                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            25            40            0.006735
# 1                            89            20            0.010095
# 2                            14            40            0.012316
# 3                            14            30            0.006991
# 4                            29            40            5.742626
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# ...

# %%
df_bank_account.dtypes
# Out:
# fraud_bool                            int64
# income                              float64
# name_email_similarity               float64
# prev_address_months_count             int64
# current_address_months_count          int64
# customer_age                          int64
# days_since_request                  float64
# intended_balcon_amount              float64
# payment_type                         object
# zip_count_4w                          int64
# velocity_6h                         float64
# velocity_24h                        float64
# velocity_4w                         float64
# bank_branch_count_8w                  int64
# date_of_birth_distinct_emails_4w      int64
# employment_status                    object
# credit_risk_score                     int64
# email_is_free                         int64
# housing_status                       object
# phone_home_valid                      int64
# phone_mobile_valid                    int64
# ...

# %%
df_bank_account['fraud_bool'].value_counts()
# Out:
# fraud_bool
# 0    988971
# 1     11029
# Name: count, dtype: int64

# %% [markdown]
# ## Online Payment Fraud Detection

# %%
df_online_payment = pd.read_csv(os.path.join(data_path, '05_online_payment.csv'))

df_online_payment['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df_online_payment['isFlaggedFraud'].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df_online_payment.dtypes
# Out:
# step                int64
# type               object
# amount            float64
# nameOrig           object
# oldbalanceOrg     float64
# newbalanceOrig    float64
# nameDest           object
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud             int64
# isFlaggedFraud      int64
# dtype: object

# %%
print("df credit card:", df.dtypes)
print("\n")
print("df_vehicle:", df_vehicle.dtypes)
print("\n")
print("df_bank_account:", df_bank_account.dtypes)
print("\n")
print("df_online_payment:", df_online_payment.dtypes)
# Out:
# df credit card: Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object
#
#
# df_vehicle: Month                   object
# WeekOfMonth              int64
# DayOfWeek               object
# Make                    object
# AccidentArea            object
# DayOfWeekClaimed        object
# MonthClaimed            object
# WeekOfMonthClaimed       int64
# Sex                     object
# MaritalStatus           object
# ...
