# %%
import sys
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Get the project root directory (parent of notebooks folder)
project_root = os.path.dirname(os.getcwd())
sys.path.insert(0, project_root)

# %%
data_path = os.path.join(project_root, 'results', 'xgb_03_fraud_oracle_results.csv')
df = pd.read_csv(data_path)
df
# Out:
#                           Model    PR-AUC  Recall@Prec>=90%  Recall@Prec>=95%  \
# 0                  Baseline XGB  0.566397          0.168478          0.108696
# 1                XGB with SMOTE  0.282122          0.016304          0.016304
# 2     XGB with Borderline SMOTE  0.300118          0.016304          0.016304
# 3             XGB with SMOTEENN  0.255257          0.010870          0.010870
# 4          XGB with PyTorch GAN  0.539306          0.168478          0.119565
# 5                XGB with CTGAN  0.562861          0.125000          0.119565
# 6  XGB with Conditional WGAN-GP  0.551254          0.146739          0.119565
#
#    Recall@5%FPR  Lift@Top-1%   FPR@0.5  F1-Score  Precision    Recall
# 0      0.668478    15.084783  0.097241  0.484553   0.345708  0.809783
# 1      0.342391     6.704348  0.185862  0.318605   0.202663  0.744565
# 2      0.402174     6.704348  0.175172  0.312195   0.201258  0.695652
# 3      0.298913     7.821739  0.245862  0.279962   0.169965  0.793478
# 4      0.625000    15.643478  0.108276  0.458204   0.320346  0.804348
# 5      0.668478    13.967391  0.104828  0.467818   0.328918  0.809783
# 6      0.635870    15.084783  0.104828  0.472613   0.331868  0.820652
